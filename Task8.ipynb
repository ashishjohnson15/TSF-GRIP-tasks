# %% [markdown]
# **Ashish Johnson**
#
# **Data Science and Business Analytics Intern**
#
#  **Topic:Timeline Analysis : Covid-19-Task 8**
#
# Dataset:https://bit.ly/30d2gdi
#
# The following code aims at providing a detailed Timeline Analysis of the Covid affected regions across the world, and visualizing them.

# %% [markdown]
# **PROBLEM STATEMENT:**
#
# Identify detailed patterns and possible conclusions regarding Covid-19 spread with basic as well as advanced charts.

# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import matplotlib.colors as mcolors

# %%
#Reading the Data
covid_data = pd.read_csv('/content/drive/MyDrive/owid-covid-data.csv');
covid_data.head(10)
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
# 5      AFG      Asia  ...           64.83                   0.511
# 6      AFG      Asia  ...           64.83                   0.511
# 7      AFG      Asia  ...           64.83                   0.511
# 8      AFG      Asia  ...           64.83                   0.511
# 9      AFG      Asia  ...           64.83                   0.511
#
# [10 rows x 59 columns]

# %%
# Analyzing the rows and columns count of the dataset
covid_data.shape
# Out:
# (75071, 59)

# %%
# Analyzing the data types of all the attributes present and their count
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75071 entries, 0 to 75070
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               75071 non-null  object
#  1   continent                              71365 non-null  object
#  2   location                               75071 non-null  object
#  3   date                                   75071 non-null  object
#  4   total_cases                            73918 non-null  float64
#  5   new_cases                              73916 non-null  float64
#  6   new_cases_smoothed                     72915 non-null  float64
#  7   total_deaths                           64679 non-null  float64
#  8   new_deaths                             64837 non-null  float64
#  9   new_deaths_smoothed                    72915 non-null  float64
#  10  total_cases_per_million                73515 non-null  float64
#  11  new_cases_per_million                  73513 non-null  float64
#  12  new_cases_smoothed_per_million         72517 non-null  float64
#  13  total_deaths_per_million               64289 non-null  float64
#  14  new_deaths_per_million                 64447 non-null  float64
#  15  new_deaths_smoothed_per_million        72517 non-null  float64
#  16  reproduction_rate                      60388 non-null  float64
#  17  icu_patients                           7759 non-null   float64
#  18  icu_patients_per_million               7759 non-null   float64
#  19  hosp_patients                          9337 non-null   float64
#  20  hosp_patients_per_million              9337 non-null   float64
#  21  weekly_icu_admissions                  683 non-null    float64
#  22  weekly_icu_admissions_per_million      683 non-null    float64
#  23  weekly_hosp_admissions                 1261 non-null   float64
#  24  weekly_hosp_admissions_per_million     1261 non-null   float64
#  25  new_tests                              34165 non-null  float64
#  26  total_tests                            33945 non-null  float64
#  27  total_tests_per_thousand               33945 non-null  float64
#  28  new_tests_per_thousand                 34165 non-null  float64
#  29  new_tests_smoothed                     39004 non-null  float64
#  30  new_tests_smoothed_per_thousand        39004 non-null  float64
#  31  positive_rate                          37720 non-null  float64
#  32  tests_per_case                         37141 non-null  float64
#  33  tests_units                            40343 non-null  object
#  34  total_vaccinations                     4052 non-null   float64
#  35  people_vaccinated                      3602 non-null   float64
#  36  people_fully_vaccinated                2391 non-null   float64
#  37  new_vaccinations                       3420 non-null   float64
#  38  new_vaccinations_smoothed              6128 non-null   float64
#  39  total_vaccinations_per_hundred         4052 non-null   float64
#  40  people_vaccinated_per_hundred          3602 non-null   float64
#  41  people_fully_vaccinated_per_hundred    2391 non-null   float64
#  42  new_vaccinations_smoothed_per_million  6128 non-null   float64
#  43  stringency_index                       64578 non-null  float64
#  44  population                             74659 non-null  float64
#  45  population_density                     70130 non-null  float64
#  46  median_age                             68155 non-null  float64
#  47  aged_65_older                          67371 non-null  float64
#  48  aged_70_older                          67771 non-null  float64
#  49  gdp_per_capita                         68378 non-null  float64
#  50  extreme_poverty                        46654 non-null  float64
#  51  cardiovasc_death_rate                  68997 non-null  float64
#  52  diabetes_prevalence                    69882 non-null  float64
#  53  female_smokers                         54221 non-null  float64
#  54  male_smokers                           53476 non-null  float64
#  55  handwashing_facilities                 34637 non-null  float64
#  56  hospital_beds_per_thousand             63136 non-null  float64
#  57  life_expectancy                        71323 non-null  float64
#  58  human_development_index                68941 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 33.8+ MB

# %%
# Identifying the columns present
covid_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# Descripting of the numerical attributes present in the dataset
covid_data.describe()
# Out:
#         total_cases      new_cases  ...  life_expectancy  human_development_index
# count  7.391800e+04   73916.000000  ...     71323.000000             68941.000000
# mean   6.586969e+05    5173.069173  ...        73.142035                 0.727823
# std    4.626117e+06   32293.280936  ...         7.552322                 0.150156
# min    1.000000e+00  -74347.000000  ...        53.280000                 0.394000
# 25%    7.220000e+02       2.000000  ...        67.880000                 0.602000
# 50%    8.176000e+03      60.000000  ...        74.530000                 0.748000
# 75%    8.798500e+04     676.000000  ...        78.730000                 0.848000
# max    1.202181e+08  880902.000000  ...        86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
#Checking for count of all the unique values present for each attribute
covid_data.nunique()
# Out:
# iso_code                                   215
# continent                                    6
# location                                   215
# date                                       440
# total_cases                              39001
# new_cases                                10299
# new_cases_smoothed                       19616
# total_deaths                             14813
# new_deaths                                2497
# new_deaths_smoothed                       5590
# total_cases_per_million                  56728
# new_cases_per_million                    32519
# new_cases_smoothed_per_million           36543
# total_deaths_per_million                 34460
# new_deaths_per_million                    6453
# new_deaths_smoothed_per_million           7666
# reproduction_rate                          355
# icu_patients                              2021
# icu_patients_per_million                  4284
# hosp_patients                             4032
# hosp_patients_per_million                 6994
# weekly_icu_admissions                      513
# weekly_icu_admissions_per_million          509
# weekly_hosp_admissions                    1123
# weekly_hosp_admissions_per_million        1119
# new_tests                                18533
# total_tests                              33077
# total_tests_per_thousand                 28642
# new_tests_per_thousand                    6074
# new_tests_smoothed                       20799
# new_tests_smoothed_per_thousand           6280
# positive_rate                              567
# tests_per_case                            4911
# tests_units                                  4
# total_vaccinations                        3873
# people_vaccinated                         3444
# people_fully_vaccinated                   2272
# new_vaccinations                          3180
# new_vaccinations_smoothed                 4490
# total_vaccinations_per_hundred            1501
# people_vaccinated_per_hundred             1232
# people_fully_vaccinated_per_hundred        643
# new_vaccinations_smoothed_per_million     2963
# stringency_index                           175
# population                                 213
# population_density                         196
# median_age                                 132
# aged_65_older                              181
# aged_70_older                              179
# gdp_per_capita                             187
# extreme_poverty                             75
# cardiovasc_death_rate                      187
# diabetes_prevalence                        139
# female_smokers                             108
# male_smokers                               124
# handwashing_facilities                      95
# hospital_beds_per_thousand                 100
# life_expectancy                            191
# human_development_index                    151
# dtype: int64

# %%
# Checking for count of NULL values for each column 
covid_data.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3706
# location                                     0
# date                                         0
# total_cases                               1153
# new_cases                                 1155
# new_cases_smoothed                        2156
# total_deaths                             10392
# new_deaths                               10234
# new_deaths_smoothed                       2156
# total_cases_per_million                   1556
# new_cases_per_million                     1558
# new_cases_smoothed_per_million            2554
# total_deaths_per_million                 10782
# new_deaths_per_million                   10624
# new_deaths_smoothed_per_million           2554
# reproduction_rate                        14683
# icu_patients                             67312
# icu_patients_per_million                 67312
# hosp_patients                            65734
# hosp_patients_per_million                65734
# weekly_icu_admissions                    74388
# weekly_icu_admissions_per_million        74388
# weekly_hosp_admissions                   73810
# weekly_hosp_admissions_per_million       73810
# new_tests                                40906
# total_tests                              41126
# total_tests_per_thousand                 41126
# new_tests_per_thousand                   40906
# new_tests_smoothed                       36067
# new_tests_smoothed_per_thousand          36067
# positive_rate                            37351
# tests_per_case                           37930
# tests_units                              34728
# total_vaccinations                       71019
# people_vaccinated                        71469
# people_fully_vaccinated                  72680
# new_vaccinations                         71651
# new_vaccinations_smoothed                68943
# total_vaccinations_per_hundred           71019
# people_vaccinated_per_hundred            71469
# people_fully_vaccinated_per_hundred      72680
# new_vaccinations_smoothed_per_million    68943
# stringency_index                         10493
# population                                 412
# population_density                        4941
# median_age                                6916
# aged_65_older                             7700
# aged_70_older                             7300
# gdp_per_capita                            6693
# extreme_poverty                          28417
# cardiovasc_death_rate                     6074
# diabetes_prevalence                       5189
# female_smokers                           20850
# male_smokers                             21595
# handwashing_facilities                   40434
# hospital_beds_per_thousand               11935
# life_expectancy                           3748
# human_development_index                   6130
# dtype: int64

# %%
# Continents in terms of occurence of covid cases on basis of iso_codes
covid_data.continent.value_counts()[0:10]
# Out:
# Africa           19706
# Europe           18142
# Asia             17926
# North America     8858
# South America     4572
# Oceania           2161
# Name: continent, dtype: int64

# %%
# Analyzing cases worldwide 
dataset = covid_data[covid_data['date']=='2020-11-15']
dataset = dataset[~dataset['location'].isin(['World','International'])]
dataset.head(10)
# Out:
#       iso_code      continent  ... life_expectancy human_development_index
# 265        AFG           Asia  ...           64.83                   0.511
# 662   OWID_AFR            NaN  ...             NaN                     NaN
# 1047       ALB         Europe  ...           78.57                   0.795
# 1432       DZA         Africa  ...           76.88                   0.748
# 1811       AND         Europe  ...           83.73                   0.868
# 2172       AGO         Africa  ...           61.15                   0.581
# 2563       ATG  North America  ...           77.02                   0.778
# 3003       ARG  South America  ...           76.67                   0.845
# 3383       ARM           Asia  ...           75.09                   0.776
# 3802  OWID_ASI            NaN  ...             NaN                     NaN
#
# [10 rows x 59 columns]

# %%
# looking at different locations
covid_data["location"].value_counts()
# Out:
# Argentina           440
# Mexico              440
# Thailand            437
# Taiwan              425
# South Korea         420
#                    ...
# Anguilla             23
# Montserrat           16
# Falkland Islands     16
# Northern Cyprus       9
# Saint Helena          1
# Name: location, Length: 215, dtype: int64

# %%
# covid cases in india

india=covid_data[covid_data["location"]=="India"]

# %%
india.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 30843      IND      Asia  ...           69.66                   0.645
# 30844      IND      Asia  ...           69.66                   0.645
# 30845      IND      Asia  ...           69.66                   0.645
# 30846      IND      Asia  ...           69.66                   0.645
# 30847      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
#Data Visualization
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=india)
plt.show()

# %%
india_last_5_days=india.tail()

# %%
# total cases last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
# total test per day

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_tests",data=india)
plt.show()

# %%
# total test last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
# covid cases in Brazil

brazil=covid_data[covid_data["location"]=="Brazil"]

# %%
brazil.head()
# Out:
#      iso_code      continent  ... life_expectancy human_development_index
# 9639      BRA  South America  ...           75.88                   0.765
# 9640      BRA  South America  ...           75.88                   0.765
# 9641      BRA  South America  ...           75.88                   0.765
# 9642      BRA  South America  ...           75.88                   0.765
# 9643      BRA  South America  ...           75.88                   0.765
#
# [5 rows x 59 columns]

# %%
brazil.tail()
# Out:
#       iso_code      continent  ... life_expectancy human_development_index
# 10018      BRA  South America  ...           75.88                   0.765
# 10019      BRA  South America  ...           75.88                   0.765
# 10020      BRA  South America  ...           75.88                   0.765
# 10021      BRA  South America  ...           75.88                   0.765
# 10022      BRA  South America  ...           75.88                   0.765
#
# [5 rows x 59 columns]

# %%
brazil_last_5_days=brazil.tail()

# %%
# total cases last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
# understanding cases of india,china and japan

india_japan_china=covid_data[(covid_data["location"]=="India") | (covid_data["location"]=="China") | (covid_data["location"]=="Japan")]

# %%
# total cases 

sns.set(rc={"figure.figsize":(15,10)})
sns.barplot(x="location",y="total_cases",data=india_japan_china,hue="date")
plt.show()

# %%
# understanding cases of germany and spain


germany_spain=covid_data[(covid_data["location"]=="Germany") | (covid_data["location"]=="Spain")]

# %%
# total cases 

sns.set(rc={"figure.figsize":(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
# getting latset data

last_day_cases=covid_data[(covid_data["date"]=="2020-12-18")]
last_day_cases
# Out:
#        iso_code continent  ... life_expectancy human_development_index
# 298         AFG      Asia  ...           64.83                   0.511
# 695    OWID_AFR       NaN  ...             NaN                     NaN
# 1080        ALB    Europe  ...           78.57                   0.795
# 1465        DZA    Africa  ...           76.88                   0.748
# 1844        AND    Europe  ...           83.73                   0.868
# ...         ...       ...  ...             ...                     ...
# 73500       VNM      Asia  ...           75.40                   0.704
# 73919  OWID_WRL       NaN  ...           72.58                   0.737
# 74259       YEM      Asia  ...           66.12                   0.470
# 74622       ZMB    Africa  ...           63.89                   0.584
# 74983       ZWE    Africa  ...           61.49                   0.571
#
# [198 rows x 59 columns]

# %%
# sorting date w.r.t to total cases

max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 73919  OWID_WRL            NaN  ...           72.58                   0.737
# 23175  OWID_EUR            NaN  ...             NaN                     NaN
# 49716  OWID_NAM            NaN  ...             NaN                     NaN
# 3835   OWID_ASI            NaN  ...             NaN                     NaN
# 71480       USA  North America  ...           78.86                   0.926
# ...         ...            ...  ...             ...                     ...
# 72715       VAT         Europe  ...           75.12                     NaN
# 61409       SLB        Oceania  ...           73.00                   0.567
# 42796       MHL        Oceania  ...           73.70                   0.704
# 57464       WSM        Oceania  ...           73.32                   0.715
# 72340       VUT        Oceania  ...           70.47                   0.609
#
# [198 rows x 59 columns]

# %%
# top 5 countries with maximum case
max_cases_country[1:6]
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 23175  OWID_EUR            NaN  ...             NaN                     NaN
# 49716  OWID_NAM            NaN  ...             NaN                     NaN
# 3835   OWID_ASI            NaN  ...             NaN                     NaN
# 71480       USA  North America  ...           78.86                   0.926
# 23593  OWID_EUN            NaN  ...             NaN                     NaN
#
# [5 rows x 59 columns]

# %%
# plot on bar plot

sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="date")
plt.show()
